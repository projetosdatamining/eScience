# %%
import pandas as pd
from sklearn import datasets
iris = datasets.load_iris()
x_values = pd.DataFrame(iris.data,columns=iris.feature_names)
y_values = pd.DataFrame(iris.target,columns=['target'])
irisDataFrame = pd.concat([x_values, y_values], axis=1)

# %%
import numpy as np
#pd.DataFrame.pivot_table(irisDataFrame, values='index', index=['target'],columns=['petal width (cm)','petal length (cm)'])
pd.DataFrame.pivot_table(irisDataFrame, 
                         index=['target'],aggfunc=np.count_nonzero)
# Out:
#         petal length (cm)  petal width (cm)  sepal length (cm)  \
# target
# 0                    50.0              50.0               50.0
# 1                    50.0              50.0               50.0
# 2                    50.0              50.0               50.0
#
#         sepal width (cm)
# target
# 0                   50.0
# 1                   50.0
# 2                   50.0

# %%
irisDataFrame.reset_index(level=0, inplace=True)
irisDataFrame.head()
# Out:
#    index  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0      0                5.1               3.5                1.4
# 1      1                4.9               3.0                1.4
# 2      2                4.7               3.2                1.3
# 3      3                4.6               3.1                1.5
# 4      4                5.0               3.6                1.4
#
#    petal width (cm)  target
# 0               0.2       0
# 1               0.2       0
# 2               0.2       0
# 3               0.2       0
# 4               0.2       0

# %%
irisDataFrame.pivot(index='index',columns='target').head()
# Out:
#        sepal length (cm)         sepal width (cm)         petal length (cm)  \
# target                 0   1   2                0   1   2                 0
# index
# 0                    5.1 NaN NaN              3.5 NaN NaN               1.4
# 1                    4.9 NaN NaN              3.0 NaN NaN               1.4
# 2                    4.7 NaN NaN              3.2 NaN NaN               1.3
# 3                    4.6 NaN NaN              3.1 NaN NaN               1.5
# 4                    5.0 NaN NaN              3.6 NaN NaN               1.4
#
#                petal width (cm)
# target   1   2                0   1   2
# index
# 0      NaN NaN              0.2 NaN NaN
# 1      NaN NaN              0.2 NaN NaN
# 2      NaN NaN              0.2 NaN NaN
# 3      NaN NaN              0.2 NaN NaN
# 4      NaN NaN              0.2 NaN NaN

# %%
pd.DataFrame.pivot_table(irisDataFrame, values='index', 
                         index=['petal length (cm)', 'petal width (cm)'],
                         columns=['target'], 
                         aggfunc=np.sum)
# Out:
# target                                  0      1      2
# petal length (cm) petal width (cm)
# 1.0               0.2                22.0    NaN    NaN
# 1.1               0.1                13.0    NaN    NaN
# 1.2               0.2                49.0    NaN    NaN
# 1.3               0.2               118.0    NaN    NaN
#                   0.3                81.0    NaN    NaN
#                   0.4                16.0    NaN    NaN
# 1.4               0.1                12.0    NaN    NaN
#                   0.2               170.0    NaN    NaN
#                   0.3                68.0    NaN    NaN
# 1.5               0.1               112.0    NaN    NaN
#                   0.2               134.0    NaN    NaN
#                   0.3                19.0    NaN    NaN
#                   0.4                67.0    NaN    NaN
# 1.6               0.2               141.0    NaN    NaN
#                   0.4                26.0    NaN    NaN
# ...
